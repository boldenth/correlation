# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame.from_items([('A', [1, 2, 3]), ('B', [4, 5, 6])])
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame.from_items([('A', [1, 2, 3]), ('B', [4, 5, 6])])

# %%
df["A"]
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
for value in df["A"]:
    print(value)
# Out:
# 1
# 2
# 3

# %%
values = np.array([value for value in df["A"]])
print(values)
print(values.min(), values.max())
# Out:
# [1 2 3]
# 1 3

# %%
type(np.array(df["A"]))
# Out:
# numpy.ndarray

# %%
ems = pd.Series()
ems
# Out:
# Series([], dtype: float64)

# %%
import datetime as dt

# %%
df.shape
# Out:
# (3, 2)

# %%
df.shape[0]
# Out:
# 3

# %%
test_list = [1, 2, "a"]

# %%
test_list
# Out:
# [1, 2, 'a']

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame.from_items([('A', [1, 2, 3]), ('B', [4, 5, 6]), ('C', [7, 8, 9])])

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
columns = [0, "B"]
labels = {0:"A", 1:"B", 2:"C"}

# %%
dfa = pd.DataFrame()

for col in columns:
    if type(col) == int:
        dfa[labels[col]] = df[labels[col]] 
    elif type(col) == str:
        dfa[col] = df[col]
        
print(df)
print(dfa)

dfx = df

dfx = dfa

dfx
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import logging

# %%
t = dt.datetime(year=1994, 
                      month=11, 
                      day=19)
t_str = str(t)\
.replace(' ', 'T') \
.replace(':','')   \
.replace('-','')   \

print(t_str)
# Out:
# 19941119T000000

# %%
t_df = pd.DataFrame.from_items([('year', [1994, 1994, 1993]), ('m', [11, 11, 12]), ('d', [30, 31, 1])])

# %%
t_df
# Out:
#    year   m   d
# 0  1994  11  30
# 1  1994  11  31
# 2  1993  12   1

# %%
new_col = []

new_col.append(t_str)

new_col
# Out:
# ['19941119T000000']

# %%
df = pd.read_csv("test/SSA_births_2000-2014.csv")

# %%
df
# Out:
#       year  month  date_of_month  day_of_week  births
# 0     2000      1              1            6    9083
# 1     2000      1              2            7    8006
# 2     2000      1              3            1   11363
# 3     2000      1              4            2   13032
# 4     2000      1              5            3   12558
# 5     2000      1              6            4   12466
# 6     2000      1              7            5   12516
# 7     2000      1              8            6    8934
# 8     2000      1              9            7    7949
# 9     2000      1             10            1   11668
# 10    2000      1             11            2   12611
# 11    2000      1             12            3   12398
# 12    2000      1             13            4   11815
# 13    2000      1             14            5   12180
# 14    2000      1             15            6    8525
# 15    2000      1             16            7    7657
# 16    2000      1             17            1   10824
# 17    2000      1             18            2   12350
# 18    2000      1             19            3   12405
# 19    2000      1             20            4   12506
# 20    2000      1             21            5   11953
# 21    2000      1             22            6    8855
# 22    2000      1             23            7    7856
# 23    2000      1             24            1   11449
# 24    2000      1             25            2   12593
# 25    2000      1             26            3   12143
# 26    2000      1             27            4   12408
# 27    2000      1             28            5   11934
# 28    2000      1             29            6    8805
# 29    2000      1             30            7    7764
# ...    ...    ...            ...          ...     ...
# 5449  2014     12              2            2   13083
# 5450  2014     12              3            3   12427
# 5451  2014     12              4            4   12384
# 5452  2014     12              5            5   11964
# 5453  2014     12              6            6    8280
# 5469        12  2014     12             22            1   12799    12
# 5470        12  2014     12             23            2   12604    12
# 5471        12  2014     12             24            3    9308    12
# 5472        12  2014     12             25            4    6749    12
# 5473        12  2014     12             26            5   10386    12
# 5474        12  2014     12             27            6    8656    12
# 5475        12  2014     12             28            7    7724    12
# 5476        12  2014     12             29            1   12811    12
# 5477        12  2014     12             30            2   13634    12
# 5478        12  2014     12             31            3   11990    12
#
# [5479 rows x 7 columns]

# %%
import calendar

# %%
print(calendar.month_abbr)
# Out:
# <calendar._localized_month object at 0x1035766d8>

# %%
abbr_to_num = {name.lower(): num for num, name in enumerate(calendar.month_abbr) if num}

# %%
abbr_to_num["JAN".lower()]
# Out:
# 1

# %%
name_to_num = {name.lower(): num for num, name \
               in enumerate(calendar.month_name) if num}

# %%
name_to_num["september".lower()]
# Out:
# 9

# %%
df.replace("year", new_col)
df
# Out:
#       beg date  year  month  date_of_month  day_of_week  births  date
# 0            1  2000      1              1            6    9083     1
# 1            1  2000      1              2            7    8006     1
# 2            1  2000      1              3            1   11363     1
# 3            1  2000      1              4            2   13032     1
# 4            1  2000      1              5            3   12558     1
# 5            1  2000      1              6            4   12466     1
# 6            1  2000      1              7            5   12516     1
# 7            1  2000      1              8            6    8934     1
# 8            1  2000      1              9            7    7949     1
# 9            1  2000      1             10            1   11668     1
# 10           1  2000      1             11            2   12611     1
# 11           1  2000      1             12            3   12398     1
# 12           1  2000      1             13            4   11815     1
# 13           1  2000      1             14            5   12180     1
# 14           1  2000      1             15            6    8525     1
# 15           1  2000      1             16            7    7657     1
# 16           1  2000      1             17            1   10824     1
# 17           1  2000      1             18            2   12350     1
# 18           1  2000      1             19            3   12405     1
# 19           1  2000      1             20            4   12506     1
# 20           1  2000      1             21            5   11953     1
# 21           1  2000      1             22            6    8855     1
# 22           1  2000      1             23            7    7856     1
# 23           1  2000      1             24            1   11449     1
# 24           1  2000      1             25            2   12593     1
# 25           1  2000      1             26            3   12143     1
# 26           1  2000      1             27            4   12408     1
# 27           1  2000      1             28            5   11934     1
# 28           1  2000      1             29            6    8805     1
# 29           1  2000      1             30            7    7764     1
# ...        ...   ...    ...            ...          ...     ...   ...
# 5449        12  2014     12              2            2   13083    12
# 5450        12  2014     12              3            3   12427    12
# 5451        12  2014     12              4            4   12384    12
# 5452        12  2014     12              5            5   11964    12
# 5453        12  2014     12              6            6    8280    12
# 5454        12  2014     12              7            7    7196    12
# 5455        12  2014     12              8            1   11773    12
# 5456        12  2014     12              9            2   12419    12
# 5457        12  2014     12             10            3   12203    12
# 5458        12  2014     12             11            4   12042    12
# 5459        12  2014     12             12            5   12001    12
# 5460        12  2014     12             13            6    8596    12
# 5461        12  2014     12             14            7    7291    12
# 5462        12  2014     12             15            1   12013    12
# 5463        12  2014     12             16            2   12748    12
# 5464        12  2014     12             17            3   12684    12
# 5465        12  2014     12             18            4   12816    12
# 5466        12  2014     12             19            5   12714    12
# 5467        12  2014     12             20            6    8465    12
# 5468        12  2014     12             21            7    7382    12
# 5469        12  2014     12             22            1   12799    12
# 5470        12  2014     12             23            2   12604    12
# 5471        12  2014     12             24            3    9308    12
# 5472        12  2014     12             25            4    6749    12
# 5473        12  2014     12             26            5   10386    12
# 5474        12  2014     12             27            6    8656    12
# 5475        12  2014     12             28            7    7724    12
# 5476        12  2014     12             29            1   12811    12
# 5477        12  2014     12             30            2   13634    12
# 5478        12  2014     12             31            3   11990    12
#
# [5479 rows x 7 columns]

# %%
dfx = pd.DataFrame.from_items([('A', [1, 2, 3]), ('B', [4, 5, 6]), ('C', [7, 8, 9])])

# %%
dfx
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
rep = [69,69,69]

# %%
dfx["A"] = rep

# %%
dfx
# Out:
#     A  B  C
# 0  69  4  7
# 1  69  5  8
# 2  69  6  9

# %%
test_dates = ["2017-11-19", "11/19/2017", "11 Nov 2017"]
import calendar as cal

# %%
test_dates = ["2017-11-19", "11/19/2017", "19 Nov 2017"]

def convert_time(time):
    
    r_str = ""
    
    if time.find('-') != -1:
        
        r_str = str(dt.datetime.strptime(time, '%Y-%m-%d'))\
                    .replace(' ', 'T') \
                    .replace(':','')   \
                    .replace('-','')
    
    elif time.find('/') != -1:
        
        r_str = str(dt.datetime.strptime(time, '%m/%d/%Y'))\
                    .replace(' ', 'T') \
                    .replace(':','')   \
                    .replace('-','')
    
    else:
        
        abbr_to_num = {name.lower(): num for num, name \
                      in enumerate(cal.month_abbr) if num}

        name_to_num = {name.lower(): num for num, name \
                      in enumerate(cal.month_name) if num}
        
        try:
            
            three = time.split()
            
            try:
                
                three = [int(three[0]), 
                         abbr_to_num[three[1].lower()], 
                         int(three[2])]
                         
            except:
                three = [three[0], name_to_num[three[1].lower()], three[2]]
            
            r_str = str(dt.datetime(year=three[2],
                                    month=three[1],
                                    day=three[0]))\
                    .replace(' ', 'T') \
                    .replace(':','')   \
                    .replace('-','')
            
        except:
            print("Fail")
            r_str = time
    
    return r_str

for s in test_dates:
    print(convert_time(s))
# Out:
# 20171119T000000
# 20171119T000000
# 20171119T000000

# %%
"11/19/2017".find('-')
# Out:
# -1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["births"].name
# Out:
# 'births'

# %%
toop = (1, 36)

first, last = toop[0], toop[-1]

# %%
first, last
# Out:
# (1, 36)

# %%
import requests

# %%
from io import StringIO

# %%
df.head()
# Out:
#    beg date  year  month  date_of_month  day_of_week  births  date
# 0         1  2000      1              1            6    9083     1
# 1         1  2000      1              2            7    8006     1
# 2         1  2000      1              3            1   11363     1
# 3         1  2000      1              4            2   13032     1
# 4         1  2000      1              5            3   12558     1

# %%
df = df[3:]

df.head()
# Out:
#    beg date  year  month  date_of_month  day_of_week  births  date
# 3         1  2000      1              4            2   13032     1
# 4         1  2000      1              5            3   12558     1
# 5         1  2000      1              6            4   12466     1
# 6         1  2000      1              7            5   12516     1
# 7         1  2000      1              8            6    8934     1

# %%
df.drop(df.index[-2])

df.head()

df.tail()
# Out:
#       beg date  year  month  date_of_month  day_of_week  births  date
# 5474        12  2014     12             27            6    8656    12
# 5475        12  2014     12             28            7    7724    12
# 5476        12  2014     12             29            1   12811    12
# 5477        12  2014     12             30            2   13634    12
# 5478        12  2014     12             31            3   11990    12
